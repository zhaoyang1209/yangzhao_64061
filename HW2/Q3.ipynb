# %% [markdown]
# ## Training a convnet from scratch on a small dataset

# %% [markdown]
# ### The relevance of deep learning for small-data problems

# %% [markdown]
# ### Downloading the data

# %%
# !unzip -qq '/fs/ess/PGS0333/BA_64061_KSU/data/dogs-vs-cats.zip'

# %%
# !unzip -qq train.zip

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=3000)
make_subset("validation", start_index=3500, end_index=4000)
make_subset("test", start_index=4500, end_index=5000)

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 180, 180, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 178, 178, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 89, 89, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 87, 87, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 43, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 41, 41, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 12545
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 6000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Fitting the model using a `Dataset`**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 188/188 [==============================] - 8s 27ms/step - loss: 0.7324 - accuracy: 0.5172 - val_loss: 0.6871 - val_accuracy: 0.5430
# Epoch 2/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.6712 - accuracy: 0.5983 - val_loss: 0.6565 - val_accuracy: 0.6070
# Epoch 3/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.5926 - accuracy: 0.6892 - val_loss: 0.6380 - val_accuracy: 0.6060
# Epoch 4/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.5402 - accuracy: 0.7313 - val_loss: 0.5304 - val_accuracy: 0.7370
# Epoch 5/30
# 188/188 [==============================] - 4s 22ms/step - loss: 0.4767 - accuracy: 0.7752 - val_loss: 0.5329 - val_accuracy: 0.7420
# Epoch 6/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.4348 - accuracy: 0.8032 - val_loss: 0.4949 - val_accuracy: 0.7840
# Epoch 7/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3787 - accuracy: 0.8332 - val_loss: 0.4657 - val_accuracy: 0.8040
# Epoch 8/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3318 - accuracy: 0.8525 - val_loss: 0.4560 - val_accuracy: 0.7920
# Epoch 9/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.2790 - accuracy: 0.8807 - val_loss: 0.4747 - val_accuracy: 0.7900
# Epoch 10/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.2211 - accuracy: 0.9090 - val_loss: 0.5171 - val_accuracy: 0.8110
# Epoch 11/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.1726 - accuracy: 0.9318 - val_loss: 1.2540 - val_accuracy: 0.7090
# Epoch 12/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.1403 - accuracy: 0.9463 - val_loss: 0.7743 - val_accuracy: 0.7950
# Epoch 13/30
# 188/188 [==============================] - 4s 22ms/step - loss: 0.1055 - accuracy: 0.9618 - val_loss: 0.8121 - val_accuracy: 0.8150
# Epoch 14/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.0942 - accuracy: 0.9667 - val_loss: 0.8993 - val_accuracy: 0.8040
# Epoch 15/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.0818 - accuracy: 0.9703 - val_loss: 0.9962 - val_accuracy: 0.8140
# Epoch 16/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.0783 - accuracy: 0.9727 - val_loss: 1.0507 - val_accuracy: 0.8080
# Epoch 17/30
# 188/188 [==============================] - 4s 23ms/step - loss: 0.0661 - accuracy: 0.9777 - val_loss: 1.3536 - val_accuracy: 0.8120
# Epoch 18/30
# 188/188 [==============================] - 5s 24ms/step - loss: 0.0683 - accuracy: 0.9777 - val_loss: 1.1773 - val_accuracy: 0.8050
# Epoch 19/30
# 188/188 [==============================] - 5s 28ms/step - loss: 0.0540 - accuracy: 0.9810 - val_loss: 1.1998 - val_accuracy: 0.8090
# Epoch 20/30
# 188/188 [==============================] - 5s 24ms/step - loss: 0.0629 - accuracy: 0.9800 - val_loss: 1.2396 - val_accuracy: 0.8090
# Epoch 21/30
# 188/188 [==============================] - 5s 24ms/step - loss: 0.0572 - accuracy: 0.9832 - val_loss: 1.5073 - val_accuracy: 0.7990
# Epoch 22/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.0626 - accuracy: 0.9808 - val_loss: 1.3569 - val_accuracy: 0.8020
# Epoch 23/30
# 188/188 [==============================] - 5s 24ms/step - loss: 0.0601 - accuracy: 0.9823 - val_loss: 1.5303 - val_accuracy: 0.8100
# Epoch 24/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.0583 - accuracy: 0.9830 - val_loss: 1.6711 - val_accuracy: 0.8110
# Epoch 25/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.0546 - accuracy: 0.9847 - val_loss: 1.6907 - val_accuracy: 0.8120
# Epoch 26/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.0550 - accuracy: 0.9852 - val_loss: 1.8387 - val_accuracy: 0.8240
# Epoch 27/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.0586 - accuracy: 0.9843 - val_loss: 1.5396 - val_accuracy: 0.8080
# Epoch 28/30
# 188/188 [==============================] - 5s 25ms/step - loss: 0.0492 - accuracy: 0.9872 - val_loss: 1.5797 - val_accuracy: 0.8050
# Epoch 29/30
# 188/188 [==============================] - 5s 24ms/step - loss: 0.0475 - accuracy: 0.9863 - val_loss: 1.8981 - val_accuracy: 0.7690
# Epoch 30/30
# 188/188 [==============================] - 5s 24ms/step - loss: 0.0379 - accuracy: 0.9892 - val_loss: 1.9365 - val_accuracy: 0.7950

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4961 - accuracy: 0.7880
# Test accuracy: 0.788

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **Training the regularized convnet**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=40,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/40
# 188/188 [==============================] - 6s 25ms/step - loss: 0.7052 - accuracy: 0.5320 - val_loss: 0.6748 - val_accuracy: 0.6010
# Epoch 2/40
# 188/188 [==============================] - 5s 25ms/step - loss: 0.6723 - accuracy: 0.6018 - val_loss: 0.6396 - val_accuracy: 0.6390
# Epoch 3/40
# Epoch 24/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3340 - accuracy: 0.8587 - val_loss: 0.4145 - val_accuracy: 0.8270
# Epoch 25/40
# 188/188 [==============================] - 5s 23ms/step - loss: 0.3319 - accuracy: 0.8615 - val_loss: 0.5372 - val_accuracy: 0.8350
# Epoch 26/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3187 - accuracy: 0.8638 - val_loss: 0.4202 - val_accuracy: 0.8680
# Epoch 27/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3008 - accuracy: 0.8782 - val_loss: 0.3619 - val_accuracy: 0.8830
# Epoch 28/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3084 - accuracy: 0.8690 - val_loss: 1.1965 - val_accuracy: 0.6640
# Epoch 29/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3230 - accuracy: 0.8672 - val_loss: 0.3916 - val_accuracy: 0.8840
# Epoch 30/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3128 - accuracy: 0.8692 - val_loss: 0.6321 - val_accuracy: 0.8560
# Epoch 31/40
# 188/188 [==============================] - 5s 23ms/step - loss: 0.3095 - accuracy: 0.8702 - val_loss: 0.5494 - val_accuracy: 0.7760
# Epoch 32/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3104 - accuracy: 0.8763 - val_loss: 0.6327 - val_accuracy: 0.8060
# Epoch 33/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3161 - accuracy: 0.8685 - val_loss: 0.2981 - val_accuracy: 0.9010
# Epoch 34/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.2967 - accuracy: 0.8750 - val_loss: 0.3781 - val_accuracy: 0.8850
# Epoch 35/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3120 - accuracy: 0.8770 - val_loss: 0.3705 - val_accuracy: 0.8930
# Epoch 36/40
# 188/188 [==============================] - 5s 23ms/step - loss: 0.3112 - accuracy: 0.8722 - val_loss: 0.3136 - val_accuracy: 0.8750
# Epoch 37/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.2870 - accuracy: 0.8795 - val_loss: 0.3360 - val_accuracy: 0.8870
# Epoch 38/40
# 188/188 [==============================] - 4s 23ms/step - loss: 0.3332 - accuracy: 0.8730 - val_loss: 0.5040 - val_accuracy: 0.8520
# Epoch 39/40
# 188/188 [==============================] - 5s 23ms/step - loss: 0.2918 - accuracy: 0.8805 - val_loss: 0.4509 - val_accuracy: 0.8250
# Epoch 40/40
# 188/188 [==============================] - 5s 23ms/step - loss: 0.3120 - accuracy: 0.8755 - val_loss: 0.5915 - val_accuracy: 0.8300

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 [==============================] - 1s 14ms/step - loss: 0.2548 - accuracy: 0.8890
# Test accuracy: 0.889
