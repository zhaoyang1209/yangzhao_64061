# %% [markdown]
# ## Training a convnet from scratch on a small dataset

# %% [markdown]
# ### The relevance of deep learning for small-data problems

# %% [markdown]
# ### Downloading the data

# %%
# !unzip -qq '/fs/ess/PGS0333/BA_64061_KSU/data/dogs-vs-cats.zip'

# %%
# !unzip -qq train.zip

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2000)

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 180, 180, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 178, 178, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 89, 89, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 87, 87, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 43, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 41, 41, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 12545
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Fitting the model using a `Dataset`**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 5s 38ms/step - loss: 0.7805 - accuracy: 0.4955 - val_loss: 0.6950 - val_accuracy: 0.5000
# Epoch 2/30
# 63/63 [==============================] - 2s 31ms/step - loss: 0.7113 - accuracy: 0.5310 - val_loss: 0.6901 - val_accuracy: 0.5490
# Epoch 3/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.6835 - accuracy: 0.5925 - val_loss: 0.6757 - val_accuracy: 0.5600
# Epoch 4/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.6605 - accuracy: 0.6360 - val_loss: 0.6473 - val_accuracy: 0.6130
# Epoch 24/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.0346 - accuracy: 0.9885 - val_loss: 2.3094 - val_accuracy: 0.7150
# Epoch 25/30
# 63/63 [==============================] - 3s 39ms/step - loss: 0.0426 - accuracy: 0.9885 - val_loss: 2.2032 - val_accuracy: 0.7420
# Epoch 26/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.0459 - accuracy: 0.9845 - val_loss: 2.4402 - val_accuracy: 0.7210
# Epoch 27/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0433 - accuracy: 0.9880 - val_loss: 2.0833 - val_accuracy: 0.7330
# Epoch 28/30
# 63/63 [==============================] - 2s 35ms/step - loss: 0.0340 - accuracy: 0.9865 - val_loss: 2.4342 - val_accuracy: 0.7460
# Epoch 29/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0542 - accuracy: 0.9845 - val_loss: 2.5255 - val_accuracy: 0.7340
# Epoch 30/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0536 - accuracy: 0.9870 - val_loss: 2.6556 - val_accuracy: 0.7520

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 [==============================] - 1s 14ms/step - loss: 0.5686 - accuracy: 0.7200
# Test accuracy: 0.720

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **Training the regularized convnet**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=200,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/200
# 63/63 [==============================] - 3s 33ms/step - loss: 0.7310 - accuracy: 0.5090 - val_loss: 5.7410 - val_accuracy: 0.5000
# Epoch 2/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.7547 - accuracy: 0.5485 - val_loss: 0.6811 - val_accuracy: 0.5460
# Epoch 3/200
# 63/63 [==============================] - 2s 31ms/step - loss: 0.6885 - accuracy: 0.5515 - val_loss: 0.6798 - val_accuracy: 0.5500
# Epoch 4/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.7101 - accuracy: 0.5825 - val_loss: 0.6716 - val_accuracy: 0.5730
# Epoch 5/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6606 - accuracy: 0.6080 - val_loss: 0.6525 - val_accuracy: 0.6110
# Epoch 6/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6500 - accuracy: 0.6360 - val_loss: 0.6738 - val_accuracy: 0.5890
# Epoch 7/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6382 - accuracy: 0.6435 - val_loss: 0.6410 - val_accuracy: 0.6090
# Epoch 8/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.6233 - accuracy: 0.6535 - val_loss: 0.6361 - val_accuracy: 0.6510
# Epoch 9/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.6116 - accuracy: 0.6755 - val_loss: 0.6319 - val_accuracy: 0.6700
# Epoch 10/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.5963 - accuracy: 0.6845 - val_loss: 0.6582 - val_accuracy: 0.6190
# Epoch 11/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.5817 - accuracy: 0.7070 - val_loss: 0.5418 - val_accuracy: 0.7230
# Epoch 12/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.5590 - accuracy: 0.7145 - val_loss: 0.5332 - val_accuracy: 0.7330
# Epoch 13/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5443 - accuracy: 0.7215 - val_loss: 0.5521 - val_accuracy: 0.7330
# Epoch 14/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0
200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2573 - accuracy: 0.9000 - val_loss: 0.5483 - val_accuracy: 0.8160
# Epoch 63/200
# 63/63 [==============================] - 2s 31ms/step - loss: 0.2280 - accuracy: 0.9085 - val_loss: 0.4967 - val_accuracy: 0.8410
# Epoch 64/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2332 - accuracy: 0.9145 - val_loss: 0.4772 - val_accuracy: 0.8300
# Epoch 65/200
# 63/63 [==============================] - 2s 32ms/step - loss: 0.2318 - accuracy: 0.9045 - val_loss: 0.4568 - val_accuracy: 0.8400
# Epoch 66/200
# 63/63 [==============================] - 2s 31ms/step - loss: 0.2339 - accuracy: 0.9045 - val_loss: 0.4767 - val_accuracy: 0.8400
# Epoch 67/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2081 - accuracy: 0.9150 - val_loss: 0.5231 - val_accuracy: 0.8280
# Epoch 68/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2204 - accuracy: 0.9165 - val_loss: 0.6153 - val_accuracy: 0.8160
# Epoch 69/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2270 - accuracy: 0.9120 - val_loss: 0.5341 - val_accuracy: 0.8350
# Epoch 70/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1938 - accuracy: 0.9210 - val_loss: 0.5562 - val_accuracy: 0.8520
# Epoch 71/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2093 - accuracy: 0.9255 - val_loss: 0.5724 - val_accuracy: 0.8400
# Epoch 72/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2002 - accuracy: 0.9250 - val_loss: 0.4344 - val_accuracy: 0.8310
# Epoch 73/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2134 - accuracy: 0.9230 - val_loss: 0.5304 - val_accuracy: 0.8320
# Epoch 74/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1906 - accuracy: 0.9240 - val_loss: 0.7809 - val_accuracy: 0.8060
# Epoch 75/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2060 - accuracy: 0.9245 - val_loss: 0.6908 - val_accuracy: 0.8070
# Epoch 76/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2041 - accuracy: 0.9270 - val_loss: 0.5624 - val_accuracy: 0.8490
# Epoch 77/200
# 63/63 [==============================] - 2s 31ms/step - loss: 0.1944 - accuracy: 0.9270 - val_loss: 0.4827 - val_accuracy: 0.8600
# Epoch 78/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1989 - accuracy: 0.9205 - val_loss: 0.6574 - val_accuracy: 0.8380
# Epoch 79/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1958 - accuracy: 0.9270 - val_loss: 0.4548 - val_accuracy: 0.8570
# Epoch 80/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1818 - accuracy: 0.9350 - val_loss: 1.0970 - val_accuracy: 0.7720
# Epoch 81/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1903 - accuracy: 0.9315 - val_loss: 0.5853 - val_accuracy: 0.8260
# Epoch 82/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2157 - accuracy: 0.9185 - val_loss: 0.6422 - val_accuracy: 0.8190
# Epoch 83/200
# 63/63 [==============================] - 2s 31ms/step - loss: 0.2025 - accuracy: 0.9250 - val_loss: 0.4815 - val_accuracy: 0.8410
# Epoch 84/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1657 - accuracy: 0.9330 - val_loss: 0.4637 - val_accuracy: 0.8620
# Epoch 85/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1810 - accuracy: 0.9320 - val_loss: 0.8128 - val_accuracy: 0.8300
# Epoch 86/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1872 - accuracy: 0.9335 - val_loss: 0.9782 - val_accuracy: 0.8040
# Epoch 87/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1699 - accuracy: 0.9345 - val_loss: 0.6602 - val_accuracy: 0.8440
# Epoch 88/200
# 63/63 [==============================] - 2s 31ms/step - loss: 0.1988 - accuracy: 0.9315 - val_loss: 0.5281 - val_accuracy: 0.8380
# Epoch 89/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1798 - accuracy: 0.9380 - val_loss: 0.5263 - val_accuracy: 0.8680
# Epoch 90/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1810 - accuracy: 0.9330 - val_loss: 0.5317 - val_accuracy: 0.8530
# Epoch 91/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1527 - accuracy: 0.9460 - val_loss: 0.8788 - val_accuracy: 0.8460
# Epoch 92/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2015 - accuracy: 0.9295 - val_loss: 0.5649 - val_accuracy: 0.8500
# Epoch 93/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1634 - accuracy: 0.9400 - val_loss: 1.0650 - val_accuracy: 0.7700
# Epoch 94/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1841 - accuracy: 0.9375 - val_loss: 0.5603 - val_accuracy: 0.8420
# Epoch 95/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1752 - accuracy: 0.9410 - val_loss: 0.8755 - val_accuracy: 0.8050
# Epoch 96/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1622 - accuracy: 0.9495 - val_loss: 0.5557 - val_accuracy: 0.8600
# Epoch 97/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1703 - accuracy: 0.9380 - val_loss: 0.5322 - val_accuracy: 0.8610
# Epoch 98/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1912 - accuracy: 0.9295 - val_loss: 0.4678 - val_accuracy: 0.8530
# Epoch 99/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1700 - accuracy: 0.9400 - val_loss: 0.5771 - val_accuracy: 0.8700
# Epoch 100/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1767 - accuracy: 0.9365 - val_loss: 0.5261 - val_accuracy: 0.8670
# Epoch 101/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1589 - accuracy: 0.9450 - val_loss: 0.5609 - val_accuracy: 0.8580
# Epoch 102/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1971 - accuracy: 0.9370 - val_loss: 0.5768 - val_accuracy: 0.8560
# Epoch 103/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1688 - accuracy: 0.9415 - val_loss: 0.4822 - val_accuracy: 0.8660
# Epoch 104/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1878 - accuracy: 0.9315 - val_loss: 0.8411 - val_accuracy: 0.8050
# Epoch 105/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1582 - accuracy: 0.9465 - val_loss: 1.0976 - val_accuracy: 0.8100
# Epoch 106/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2094 - accuracy: 0.9255 - val_loss: 0.6068 - val_accuracy: 0.8450
# Epoch 107/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1686 - accuracy: 0.9415 - val_loss: 0.7329 - val_accuracy: 0.8400
# Epoch 108/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1941 - accuracy: 0.9360 - val_loss: 0.5963 - val_accuracy: 0.8570
# Epoch 109/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1716 - accuracy: 0.9435 - val_loss: 0.8653 - val_accuracy: 0.8070
# Epoch 110/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1912 - accuracy: 0.9305 - val_loss: 0.5568 - val_accuracy: 0.8560
# Epoch 111/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1739 - accuracy: 0.9335 - val_loss: 1.2722 - val_accuracy: 0.8060
# Epoch 112/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1802 - accuracy: 0.9415 - val_loss: 0.5916 - val_accuracy: 0.8520
# Epoch 113/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1779 - accuracy: 0.9430 - val_loss: 0.5921 - val_accuracy: 0.8480
# Epoch 114/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1607 - accuracy: 0.9455 - val_loss: 0.6020 - val_accuracy: 0.8690
# Epoch 115/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1824 - accuracy: 0.9370 - val_loss: 0.5810 - val_accuracy: 0.8220
# Epoch 116/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1743 - accuracy: 0.9450 - val_loss: 0.6685 - val_accuracy: 0.8160
# Epoch 117/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1782 - accuracy: 0.9380 - val_loss: 1.0241 - val_accuracy: 0.8350
# Epoch 118/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1579 - accuracy: 0.9490 - val_loss: 0.6485 - val_accuracy: 0.8430
# Epoch 119/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1879 - accuracy: 0.9390 - val_loss: 0.6047 - val_accuracy: 0.8700
# Epoch 120/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1681 - accuracy: 0.9385 - val_loss: 0.5790 - val_accuracy: 0.8400
# Epoch 121/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1958 - accuracy: 0.9355 - val_loss: 0.5764 - val_accuracy: 0.8330
# Epoch 122/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1972 - accuracy: 0.9350 - val_loss: 0.4660 - val_accuracy: 0.8650
# Epoch 123/200
# 63/63 [==============================] - 2s 28ms/step - loss: 0.1889 - accuracy: 0.9410 - val_loss: 0.8103 - val_accuracy: 0.8360
# Epoch 124/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1847 - accuracy: 0.9360 - val_loss: 0.6151 - val_accuracy: 0.8440
# Epoch 125/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1799 - accuracy: 0.9345 - val_loss: 0.6915 - val_accuracy: 0.8570
# Epoch 126/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1889 - accuracy: 0.9310 - val_loss: 0.6695 - val_accuracy: 0.8420
# Epoch 127/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1928 - accuracy: 0.9455 - val_loss: 0.5940 - val_accuracy: 0.8760
# Epoch 128/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1511 - accuracy: 0.9515 - val_loss: 0.9445 - val_accuracy: 0.8140
# Epoch 129/200
# 63/63 [==============================] - 2s 28ms/step - loss: 0.1600 - accuracy: 0.9430 - val_loss: 0.7250 - val_accuracy: 0.8590
# Epoch 130/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1715 - accuracy: 0.9455 - val_loss: 0.6363 - val_accuracy: 0.8630
# Epoch 131/200
# 63/63 [==============================] - 2s 28ms/step - loss: 0.1547 - accuracy: 0.9435 - val_loss: 1.2436 - val_accuracy: 0.7910
# Epoch 132/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2233 - accuracy: 0.9315 - val_loss: 0.6896 - val_accuracy: 0.8420
# Epoch 133/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1693 - accuracy: 0.9410 - val_loss: 0.8859 - val_accuracy: 0.8230
# Epoch 134/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1939 - accuracy: 0.9415 - val_loss: 0.6658 - val_accuracy: 0.8490
# Epoch 135/200
# 63/63 [==============================] - 2s 28ms/step - loss: 0.1884 - accuracy: 0.9400 - val_loss: 0.6569 - val_accuracy: 0.8680
# Epoch 136/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1884 - accuracy: 0.9410 - val_loss: 0.5930 - val_accuracy: 0.8510
# Epoch 137/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1875 - accuracy: 0.9410 - val_loss: 0.5779 - val_accuracy: 0.8690
# Epoch 138/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1714 - accuracy: 0.9440 - val_loss: 0.7471 - val_accuracy: 0.8400
# Epoch 139/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1965 - accuracy: 0.9420 - val_loss: 0.6694 - val_accuracy: 0.8540
# Epoch 140/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1516 - accuracy: 0.9470 - val_loss: 0.8895 - val_accuracy: 0.8140
# Epoch 141/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1815 - accuracy: 0.9390 - val_loss: 0.6993 - val_accuracy: 0.8540
# Epoch 142/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1667 - accuracy: 0.9485 - val_loss: 0.6576 - val_accuracy: 0.8430
# Epoch 143/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1773 - accuracy: 0.9450 - val_loss: 0.5814 - val_accuracy: 0.8430
# Epoch 144/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2104 - accuracy: 0.9315 - val_loss: 0.8592 - val_accuracy: 0.8070
# Epoch 145/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1761 - accuracy: 0.9395 - val_loss: 0.6740 - val_accuracy: 0.8670
# Epoch 146/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1652 - accuracy: 0.9400 - val_loss: 0.9615 - val_accuracy: 0.8430
# Epoch 147/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1853 - accuracy: 0.9365 - val_loss: 0.8964 - val_accuracy: 0.8680
# Epoch 148/200
# 63/63 [==============================] - 2s 28ms/step - loss: 0.1694 - accuracy: 0.9420 - val_loss: 0.8591 - val_accuracy: 0.8380
# Epoch 149/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1833 - accuracy: 0.9420 - val_loss: 0.9011 - val_accuracy: 0.8390
# Epoch 150/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1777 - accuracy: 0.9435 - val_loss: 0.8592 - val_accuracy: 0.8590
# Epoch 151/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1683 - accuracy: 0.9510 - val_loss: 0.8762 - val_accuracy: 0.8610
# Epoch 152/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1730 - accuracy: 0.9410 - val_loss: 0.7828 - val_accuracy: 0.8700
# Epoch 153/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1856 - accuracy: 0.9435 - val_loss: 1.0638 - val_accuracy: 0.8500
# Epoch 154/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1681 - accuracy: 0.9495 - val_loss: 0.7408 - val_accuracy: 0.8670
# Epoch 155/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1584 - accuracy: 0.9535 - val_loss: 1.4537 - val_accuracy: 0.8350
# Epoch 156/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1793 - accuracy: 0.9515 - val_loss: 0.9412 - val_accuracy: 0.8050
# Epoch 157/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1859 - accuracy: 0.9375 - val_loss: 0.6497 - val_accuracy: 0.8750
# Epoch 158/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1642 - accuracy: 0.9455 - val_loss: 0.8184 - val_accuracy: 0.8360
# Epoch 159/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1800 - accuracy: 0.9465 - val_loss: 0.7755 - val_accuracy: 0.8330
# Epoch 160/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1721 - accuracy: 0.9525 - val_loss: 0.6314 - val_accuracy: 0.8620
# Epoch 161/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1721 - accuracy: 0.9430 - val_loss: 0.8722 - val_accuracy: 0.8510
# Epoch 162/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1678 - accuracy: 0.9500 - val_loss: 0.7598 - val_accuracy: 0.8690
# Epoch 163/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1790 - accuracy: 0.9450 - val_loss: 0.8299 - val_accuracy: 0.8600
# Epoch 164/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1594 - accuracy: 0.9535 - val_loss: 0.7923 - val_accuracy: 0.8670
# Epoch 165/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1816 - accuracy: 0.9435 - val_loss: 1.0357 - val_accuracy: 0.8260
# Epoch 166/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2155 - accuracy: 0.9410 - val_loss: 0.7153 - val_accuracy: 0.8640
# Epoch 167/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1574 - accuracy: 0.9540 - val_loss: 0.7509 - val_accuracy: 0.8810
# Epoch 168/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1792 - accuracy: 0.9535 - val_loss: 1.0650 - val_accuracy: 0.8640
# Epoch 169/200
# 63/63 [==============================] - 2s 28ms/step - loss: 0.1715 - accuracy: 0.9575 - val_loss: 0.8354 - val_accuracy: 0.8700
# Epoch 170/200
# 63/63 [==============================] - 2s 28ms/step - loss: 0.2273 - accuracy: 0.9460 - val_loss: 0.6748 - val_accuracy: 0.8260
# Epoch 171/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1893 - accuracy: 0.9440 - val_loss: 0.5682 - val_accuracy: 0.8640
# Epoch 172/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2197 - accuracy: 0.9360 - val_loss: 0.6531 - val_accuracy: 0.8510
# Epoch 173/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1922 - accuracy: 0.9415 - val_loss: 1.0460 - val_accuracy: 0.8660
# Epoch 174/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1666 - accuracy: 0.9445 - val_loss: 1.2242 - val_accuracy: 0.8690
# Epoch 175/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2277 - accuracy: 0.9390 - val_loss: 0.6398 - val_accuracy: 0.8370
# Epoch 176/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1971 - accuracy: 0.9460 - val_loss: 0.6571 - val_accuracy: 0.8630
# Epoch 177/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1942 - accuracy: 0.9435 - val_loss: 0.7406 - val_accuracy: 0.8710
# Epoch 178/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1868 - accuracy: 0.9405 - val_loss: 0.6926 - val_accuracy: 0.8190
# Epoch 179/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2043 - accuracy: 0.9335 - val_loss: 0.5985 - val_accuracy: 0.8640
# Epoch 180/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1830 - accuracy: 0.9465 - val_loss: 0.8304 - val_accuracy: 0.8620
# Epoch 181/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1790 - accuracy: 0.9560 - val_loss: 1.0029 - val_accuracy: 0.8500
# Epoch 182/200
# 63/63 [==============================] - 2s 28ms/step - loss: 0.1896 - accuracy: 0.9505 - val_loss: 1.9781 - val_accuracy: 0.7950
# Epoch 183/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2125 - accuracy: 0.9440 - val_loss: 0.6434 - val_accuracy: 0.8630
# Epoch 184/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2210 - accuracy: 0.9380 - val_loss: 0.7368 - val_accuracy: 0.8700
# Epoch 185/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1361 - accuracy: 0.9530 - val_loss: 0.8198 - val_accuracy: 0.8630
# Epoch 186/200
# 63/63 [==============================] - 2s 28ms/step - loss: 0.2103 - accuracy: 0.9460 - val_loss: 0.5754 - val_accuracy: 0.8770
# Epoch 187/200
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2029 - accuracy: 0.9395 - val_loss: 0.7463 - val_accuracy: 0.8840
# Epoch 188/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1749 - accuracy: 0.9480 - val_loss: 0.7469 - val_accuracy: 0.8490
# Epoch 189/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2015 - accuracy: 0.9505 - val_loss: 0.7380 - val_accuracy: 0.8490
# Epoch 190/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1960 - accuracy: 0.9375 - val_loss: 0.6807 - val_accuracy: 0.8540
# Epoch 191/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1514 - accuracy: 0.9515 - val_loss: 0.7958 - val_accuracy: 0.8480
# Epoch 192/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1950 - accuracy: 0.9425 - val_loss: 0.7536 - val_accuracy: 0.8730
# Epoch 193/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2173 - accuracy: 0.9420 - val_loss: 1.1521 - val_accuracy: 0.8500
# Epoch 194/200
# 63/63 [==============================] - 2s 31ms/step - loss: 0.1983 - accuracy: 0.9485 - val_loss: 0.7277 - val_accuracy: 0.8700
# Epoch 195/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2092 - accuracy: 0.9475 - val_loss: 0.7607 - val_accuracy: 0.8660
# Epoch 196/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1971 - accuracy: 0.9520 - val_loss: 1.0560 - val_accuracy: 0.8660
# Epoch 197/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1835 - accuracy: 0.9465 - val_loss: 0.8536 - val_accuracy: 0.8360
# Epoch 198/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2156 - accuracy: 0.9470 - val_loss: 1.1288 - val_accuracy: 0.8530
# Epoch 199/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2544 - accuracy: 0.9335 - val_loss: 0.7169 - val_accuracy: 0.8710
# Epoch 200/200
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2292 - accuracy: 0.9450 - val_loss: 0.7872 - val_accuracy: 0.8920

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 [==============================] - 1s 14ms/step - loss: 0.4423 - accuracy: 0.8370
# Test accuracy: 0.837
