# %% [markdown]
# ## Training a convnet from scratch on a small dataset

# %% [markdown]
# ### The relevance of deep learning for small-data problems

# %% [markdown]
# ### Downloading the data

# %%
# !unzip -qq '/fs/ess/PGS0333/BA_64061_KSU/data/dogs-vs-cats.zip'

# %%
# !unzip -qq train.zip

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2000)

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 180, 180, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 178, 178, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 89, 89, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 87, 87, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 43, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 41, 41, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 12545
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Fitting the model using a `Dataset`**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 [==============================] - 6s 39ms/step - loss: 0.7850 - accuracy: 0.4935 - val_loss: 0.6902 - val_accuracy: 0.5120
# Epoch 2/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.7026 - accuracy: 0.5395 - val_loss: 0.6766 - val_accuracy: 0.5400
# Epoch 3/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.6807 - accuracy: 0.6035 - val_loss: 0.6428 - val_accuracy: 0.6560
# Epoch 4/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.6381 - accuracy: 0.6600 - val_loss: 0.6252 - val_accuracy: 0.6360
# Epoch 5/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.5904 - accuracy: 0.7000 - val_loss: 0.6454 - val_accuracy: 0.6630
# Epoch 6/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5481 - accuracy: 0.7385 - val_loss: 0.7320 - val_accuracy: 0.6470
# Epoch 7/30
# 63/63 [==============================] - 3s 34ms/step - loss: 0.5209 - accuracy: 0.7440 - val_loss: 0.5971 - val_accuracy: 0.6880
# Epoch 8/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4687 - accuracy: 0.7655 - val_loss: 0.5824 - val_accuracy: 0.7140
# Epoch 9/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4194 - accuracy: 0.8125 - val_loss: 0.5941 - val_accuracy: 0.7180
# Epoch 10/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.3598 - accuracy: 0.8470 - val_loss: 1.3592 - val_accuracy: 0.6380
# Epoch 11/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.3305 - accuracy: 0.8680 - val_loss: 0.6464 - val_accuracy: 0.7190
# Epoch 12/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2530 - accuracy: 0.8905 - val_loss: 0.8035 - val_accuracy: 0.7210
# Epoch 13/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2198 - accuracy: 0.9065 - val_loss: 0.8703 - val_accuracy: 0.7140
# Epoch 14/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1648 - accuracy: 0.9390 - val_loss: 0.9481 - val_accuracy: 0.7240
# Epoch 15/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1449 - accuracy: 0.9430 - val_loss: 1.1914 - val_accuracy: 0.6750
# Epoch 16/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.1110 - accuracy: 0.9605 - val_loss: 1.1970 - val_accuracy: 0.6970
# Epoch 17/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.0881 - accuracy: 0.9655 - val_loss: 1.6213 - val_accuracy: 0.7260
# Epoch 18/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.0756 - accuracy: 0.9735 - val_loss: 1.7904 - val_accuracy: 0.6840
# Epoch 19/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.0904 - accuracy: 0.9665 - val_loss: 1.5836 - val_accuracy: 0.7040
# Epoch 20/30
# 63/63 [==============================] - 2s 35ms/step - loss: 0.0419 - accuracy: 0.9855 - val_loss: 3.1465 - val_accuracy: 0.6560
# Epoch 21/30
# 63/63 [==============================] - 2s 31ms/step - loss: 0.0880 - accuracy: 0.9800 - val_loss: 1.6193 - val_accuracy: 0.7230
# Epoch 22/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1212 - accuracy: 0.9750 - val_loss: 1.6889 - val_accuracy: 0.7040
# Epoch 23/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.0375 - accuracy: 0.9900 - val_loss: 1.8216 - val_accuracy: 0.7110
# Epoch 24/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0520 - accuracy: 0.9900 - val_loss: 1.9279 - val_accuracy: 0.7150
# Epoch 25/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0355 - accuracy: 0.9855 - val_loss: 2.1107 - val_accuracy: 0.6920
# Epoch 26/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0607 - accuracy: 0.9790 - val_loss: 1.9529 - val_accuracy: 0.7320
# Epoch 27/30
# 63/63 [==============================] - 2s 30ms/step - loss: 0.0668 - accuracy: 0.9820 - val_loss: 1.8307 - val_accuracy: 0.7320
# Epoch 28/30
# 63/63 [==============================] - 2s 29ms/step - loss: 0.0344 - accuracy: 0.9890 - val_loss: 2.7575 - val_accuracy: 0.6630
# Epoch 29/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.0368 - accuracy: 0.9860 - val_loss: 2.3006 - val_accuracy: 0.7260
# Epoch 30/30
# 63/63 [==============================] - 2s 34ms/step - loss: 0.0465 - accuracy: 0.9855 - val_loss: 2.5217 - val_accuracy: 0.7110

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 [==============================] - 1s 14ms/step - loss: 0.6111 - accuracy: 0.6960
# Test accuracy: 0.696

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **Training the regularized convnet**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 4s 42ms/step - loss: 0.7055 - accuracy: 0.5015 - val_loss: 1.3906 - val_accuracy: 0.5000
# Epoch 2/100
# 63/63 [==============================] - 2s 36ms/step - loss: 0.7184 - accuracy: 0.5305 - val_loss: 0.6858 - val_accuracy: 0.5340
# Epoch 3/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.6737 - accuracy: 0.5745 - val_loss: 0.6745 - val_accuracy: 0.5260
# Epoch 4/100
# 63/63 [==============================] - 3s 39ms/step - loss: 0.7180 - accuracy: 0.6105 - val_loss: 0.6780 - val_accuracy: 0.5450
# Epoch 5/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6481 - accuracy: 0.6245 - val_loss: 0.6701 - val_accuracy: 0.5670
# Epoch 6/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6425 - accuracy: 0.6360 - val_loss: 0.9970 - val_accuracy: 0.5310
# Epoch 7/100
# 63/63 [==============================] - 2s 31ms/step - loss: 0.6346 - accuracy: 0.6245 - val_loss: 0.6280 - val_accuracy: 0.6510
# Epoch 8/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.6037 - accuracy: 0.6900 - val_loss: 0.5820 - val_accuracy: 0.6920
# Epoch 9/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5961 - accuracy: 0.6955 - val_loss: 0.6364 - val_accuracy: 0.6230
# Epoch 10/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.6111 - accuracy: 0.6880 - val_loss: 0.5622 - val_accuracy: 0.6950
# Epoch 11/100
# 63/63 [==============================] - 3s 39ms/step - loss: 0.5703 - accuracy: 0.7095 - val_loss: 0.5626 - val_accuracy: 0.7000
# Epoch 12/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5663 - accuracy: 0.7130 - val_loss: 0.5752 - val_accuracy: 0.6950
# Epoch 13/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.5535 - accuracy: 0.7270 - val_loss: 0.5602 - val_accuracy: 0.7090
# Epoch 14/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5669 - accuracy: 0.7065 - val_loss: 0.5508 - val_accuracy: 0.7390
# Epoch 15/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.5413 - accuracy: 0.7305 - val_loss: 0.5781 - val_accuracy: 0.6990
# Epoch 16/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.5249 - accuracy: 0.7380 - val_loss: 0.6436 - val_accuracy: 0.6620
# Epoch 17/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.5035 - accuracy: 0.7540 - val_loss: 0.4980 - val_accuracy: 0.7320
# Epoch 18/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4968 - accuracy: 0.7665 - val_loss: 0.4951 - val_accuracy: 0.7490
# Epoch 19/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.4975 - accuracy: 0.7520 - val_loss: 0.5126 - val_accuracy: 0.7510
# Epoch 20/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4953 - accuracy: 0.7700 - val_loss: 0.4604 - val_accuracy: 0.7770
# Epoch 21/100
# 63/63 [==============================] - 2s 32ms/step - loss: 0.4684 - accuracy: 0.7780 - val_loss: 0.4910 - val_accuracy: 0.7750
# Epoch 22/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4635 - accuracy: 0.7775 - val_loss: 0.6923 - val_accuracy: 0.7110
# Epoch 23/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.4549 - accuracy: 0.7820 - val_loss: 0.4729 - val_accuracy: 0.7710
# Epoch 24/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.4602 - accuracy: 0.7840 - val_loss: 0.4617 - val_accuracy: 0.7780
# Epoch 25/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.4492 - accuracy: 0.7950 - val_loss: 0.4464 - val_accuracy: 0.7950
# Epoch 26/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4541 - accuracy: 0.7965 - val_loss: 0.4817 - val_accuracy: 0.7720
# Epoch 27/100
# 63/63 [==============================] - 3s 35ms/step - loss: 0.4134 - accuracy: 0.8060 - val_loss: 0.4415 - val_accuracy: 0.7930
# Epoch 28/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4165 - accuracy: 0.8090 - val_loss: 0.5624 - val_accuracy: 0.7420
# Epoch 29/100
# 63/63 [==============================] - 3s 43ms/step - loss: 0.4254 - accuracy: 0.8125 - val_loss: 0.5189 - val_accuracy: 0.7590
# Epoch 30/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4117 - accuracy: 0.8040 - val_loss: 0.4351 - val_accuracy: 0.8050
# Epoch 31/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.4132 - accuracy: 0.8220 - val_loss: 0.4521 - val_accuracy: 0.7970
# Epoch 32/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.3960 - accuracy: 0.8170 - val_loss: 0.4994 - val_accuracy: 0.7990
# Epoch 33/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.3902 - accuracy: 0.8245 - val_loss: 0.4844 - val_accuracy: 0.7820
# Epoch 34/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.3694 - accuracy: 0.8395 - val_loss: 0.4862 - val_accuracy: 0.7840
# Epoch 35/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.3886 - accuracy: 0.8320 - val_loss: 0.4312 - val_accuracy: 0.8120
# Epoch 36/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.3468 - accuracy: 0.8530 - val_loss: 0.4585 - val_accuracy: 0.8130
# Epoch 37/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.3704 - accuracy: 0.8305 - val_loss: 0.5925 - val_accuracy: 0.7690
# Epoch 38/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.3433 - accuracy: 0.8500 - val_loss: 0.6074 - val_accuracy: 0.7460
# Epoch 39/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.3609 - accuracy: 0.8485 - val_loss: 0.6337 - val_accuracy: 0.7280
# Epoch 40/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.3363 - accuracy: 0.8530 - val_loss: 0.5230 - val_accuracy: 0.7630
# Epoch 41/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.3178 - accuracy: 0.8530 - val_loss: 0.6286 - val_accuracy: 0.7760
# Epoch 42/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.3271 - accuracy: 0.8575 - val_loss: 0.5126 - val_accuracy: 0.7820
# Epoch 43/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.3345 - accuracy: 0.8530 - val_loss: 0.4536 - val_accuracy: 0.7970
# Epoch 44/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.3130 - accuracy: 0.8655 - val_loss: 0.4515 - val_accuracy: 0.8150
# Epoch 45/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.3046 - accuracy: 0.8680 - val_loss: 0.4484 - val_accuracy: 0.8290
# Epoch 46/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.3088 - accuracy: 0.8625 - val_loss: 0.5996 - val_accuracy: 0.7920
# Epoch 47/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.3084 - accuracy: 0.8675 - val_loss: 0.4632 - val_accuracy: 0.8020
# Epoch 48/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2970 - accuracy: 0.8770 - val_loss: 0.4749 - val_accuracy: 0.8170
# Epoch 49/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2915 - accuracy: 0.8775 - val_loss: 0.5019 - val_accuracy: 0.8180
# Epoch 50/100
# 63/63 [==============================] - 3s 39ms/step - loss: 0.3000 - accuracy: 0.8790 - val_loss: 0.5276 - val_accuracy: 0.8140
# Epoch 51/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2779 - accuracy: 0.8940 - val_loss: 0.4704 - val_accuracy: 0.8200
# Epoch 52/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.2980 - accuracy: 0.8805 - val_loss: 0.4631 - val_accuracy: 0.8200
# Epoch 53/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.2809 - accuracy: 0.8830 - val_loss: 0.4749 - val_accuracy: 0.8260
# Epoch 54/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2758 - accuracy: 0.8885 - val_loss: 0.4462 - val_accuracy: 0.8120
# Epoch 55/100
# 63/63 [==============================] - 2s 36ms/step - loss: 0.2738 - accuracy: 0.8955 - val_loss: 0.4988 - val_accuracy: 0.8200
# Epoch 56/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2601 - accuracy: 0.8895 - val_loss: 0.4742 - val_accuracy: 0.8310
# Epoch 57/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2584 - accuracy: 0.8900 - val_loss: 0.6698 - val_accuracy: 0.7740
# Epoch 58/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2421 - accuracy: 0.8985 - val_loss: 0.9795 - val_accuracy: 0.7640
# Epoch 59/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2605 - accuracy: 0.8965 - val_loss: 0.5350 - val_accuracy: 0.8220
# Epoch 60/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2542 - accuracy: 0.9025 - val_loss: 0.4911 - val_accuracy: 0.8430
# Epoch 61/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2367 - accuracy: 0.8990 - val_loss: 0.4540 - val_accuracy: 0.8470
# Epoch 62/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2595 - accuracy: 0.8995 - val_loss: 0.4978 - val_accuracy: 0.8040
# Epoch 63/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2233 - accuracy: 0.9115 - val_loss: 0.5541 - val_accuracy: 0.7910
# Epoch 64/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2449 - accuracy: 0.9015 - val_loss: 0.5504 - val_accuracy: 0.8130
# Epoch 65/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2298 - accuracy: 0.9090 - val_loss: 0.6453 - val_accuracy: 0.8240
# Epoch 66/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2288 - accuracy: 0.9105 - val_loss: 0.4414 - val_accuracy: 0.8300
# Epoch 67/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.2310 - accuracy: 0.9065 - val_loss: 0.4575 - val_accuracy: 0.7980
# Epoch 68/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2380 - accuracy: 0.9050 - val_loss: 0.5809 - val_accuracy: 0.8240
# Epoch 69/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2516 - accuracy: 0.9085 - val_loss: 0.7940 - val_accuracy: 0.7780
# Epoch 70/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2266 - accuracy: 0.9135 - val_loss: 0.4806 - val_accuracy: 0.8200
# Epoch 71/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.2129 - accuracy: 0.9150 - val_loss: 0.5682 - val_accuracy: 0.8110
# Epoch 72/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.2382 - accuracy: 0.9035 - val_loss: 0.5378 - val_accuracy: 0.8330
# Epoch 73/100
# 63/63 [==============================] - 3s 44ms/step - loss: 0.2257 - accuracy: 0.9125 - val_loss: 0.7451 - val_accuracy: 0.7840
# Epoch 74/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2123 - accuracy: 0.9150 - val_loss: 0.6320 - val_accuracy: 0.8100
# Epoch 75/100
# 63/63 [==============================] - 3s 39ms/step - loss: 0.2019 - accuracy: 0.9250 - val_loss: 0.7813 - val_accuracy: 0.8320
# Epoch 76/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.2177 - accuracy: 0.9225 - val_loss: 0.5963 - val_accuracy: 0.8280
# Epoch 77/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.2016 - accuracy: 0.9235 - val_loss: 0.5611 - val_accuracy: 0.8420
# Epoch 78/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.2481 - accuracy: 0.9065 - val_loss: 0.5177 - val_accuracy: 0.8450
# Epoch 79/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2098 - accuracy: 0.9215 - val_loss: 0.4650 - val_accuracy: 0.8490
# Epoch 80/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2114 - accuracy: 0.9220 - val_loss: 0.4693 - val_accuracy: 0.8530
# Epoch 81/100
# 63/63 [==============================] - 2s 29ms/step - loss: 0.2004 - accuracy: 0.9280 - val_loss: 0.5974 - val_accuracy: 0.8350
# Epoch 82/100
# 63/63 [==============================] - 2s 31ms/step - loss: 0.2047 - accuracy: 0.9205 - val_loss: 0.9960 - val_accuracy: 0.7840
# Epoch 83/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2104 - accuracy: 0.9155 - val_loss: 0.4997 - val_accuracy: 0.8680
# Epoch 84/100
# 63/63 [==============================] - 3s 39ms/step - loss: 0.2073 - accuracy: 0.9320 - val_loss: 0.6169 - val_accuracy: 0.8300
# Epoch 85/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2238 - accuracy: 0.9165 - val_loss: 0.5398 - val_accuracy: 0.8200
# Epoch 86/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1913 - accuracy: 0.9300 - val_loss: 0.5185 - val_accuracy: 0.8670
# Epoch 87/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.1881 - accuracy: 0.9325 - val_loss: 0.6586 - val_accuracy: 0.8240
# Epoch 88/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1904 - accuracy: 0.9340 - val_loss: 0.6219 - val_accuracy: 0.8340
# Epoch 89/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2027 - accuracy: 0.9285 - val_loss: 0.7337 - val_accuracy: 0.8530
# Epoch 90/100
# 63/63 [==============================] - 2s 31ms/step - loss: 0.1910 - accuracy: 0.9270 - val_loss: 0.8600 - val_accuracy: 0.8320
# Epoch 91/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1955 - accuracy: 0.9280 - val_loss: 0.7320 - val_accuracy: 0.8500
# Epoch 92/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.1971 - accuracy: 0.9230 - val_loss: 1.0192 - val_accuracy: 0.7960
# Epoch 93/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2157 - accuracy: 0.9230 - val_loss: 0.7227 - val_accuracy: 0.8420
# Epoch 94/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.1891 - accuracy: 0.9325 - val_loss: 0.6981 - val_accuracy: 0.8360
# Epoch 95/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2095 - accuracy: 0.9270 - val_loss: 1.3691 - val_accuracy: 0.7630
# Epoch 96/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.2173 - accuracy: 0.9245 - val_loss: 0.5408 - val_accuracy: 0.8330
# Epoch 97/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.1898 - accuracy: 0.9270 - val_loss: 0.7323 - val_accuracy: 0.8300
# Epoch 98/100
# 63/63 [==============================] - 2s 35ms/step - loss: 0.2091 - accuracy: 0.9315 - val_loss: 0.9095 - val_accuracy: 0.8080
# Epoch 99/100
# 63/63 [==============================] - 2s 34ms/step - loss: 0.2025 - accuracy: 0.9265 - val_loss: 0.5425 - val_accuracy: 0.8460
# Epoch 100/100
# 63/63 [==============================] - 2s 30ms/step - loss: 0.1794 - accuracy: 0.9355 - val_loss: 0.7489 - val_accuracy: 0.8240

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 [==============================] - 1s 15ms/step - loss: 0.4730 - accuracy: 0.7910
# Test accuracy: 0.791
