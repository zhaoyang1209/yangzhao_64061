# %% [markdown]
# ## Training a convnet from scratch on a small dataset

# %% [markdown]
# ### The relevance of deep learning for small-data problems

# %% [markdown]
# ### Downloading the data

# %%
# !unzip -qq '/fs/ess/PGS0333/BA_64061_KSU/data/dogs-vs-cats.zip'

# %%
# !unzip -qq train.zip

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("cats_vs_dogs_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname,
                            dst=dir / fname)

make_subset("train", start_index=0, end_index=2000)
make_subset("validation", start_index=2000, end_index=2500)
make_subset("test", start_index=2500, end_index=3000)

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 180, 180, 3)]     0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 178, 178, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 89, 89, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 87, 87, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 43, 43, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 41, 41, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 12545
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configuring the model for training**

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# ### Data preprocessing

# %% [markdown]
# **Using `image_dataset_from_directory` to read images**

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 4000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.

# %%
import numpy as np
import tensorflow as tf
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# **Displaying the shapes of the data and labels yielded by the `Dataset`**

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Fitting the model using a `Dataset`**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# 125/125 [==============================] - 9s 27ms/step - loss: 0.7883 - accuracy: 0.5242 - val_loss: 0.6851 - val_accuracy: 0.5510
# Epoch 2/30
# 125/125 [==============================] - 4s 29ms/step - loss: 0.6808 - accuracy: 0.5800 - val_loss: 0.6380 - val_accuracy: 0.6750
# Epoch 3/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.6264 - accuracy: 0.6687 - val_loss: 0.5843 - val_accuracy: 0.6840
# Epoch 4/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.5669 - accuracy: 0.7028 - val_loss: 0.6120 - val_accuracy: 0.6900
# Epoch 5/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.5204 - accuracy: 0.7473 - val_loss: 0.5409 - val_accuracy: 0.7360
# Epoch 6/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4710 - accuracy: 0.7753 - val_loss: 0.4873 - val_accuracy: 0.7680
# Epoch 7/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.4194 - accuracy: 0.8015 - val_loss: 0.4950 - val_accuracy: 0.7980
# Epoch 8/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3654 - accuracy: 0.8388 - val_loss: 0.4890 - val_accuracy: 0.8000
# Epoch 9/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3002 - accuracy: 0.8717 - val_loss: 0.5770 - val_accuracy: 0.7920
# Epoch 10/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2338 - accuracy: 0.8985 - val_loss: 0.7377 - val_accuracy: 0.7480
# Epoch 11/30
# 125/125 [==============================] - 5s 40ms/step - loss: 0.2033 - accuracy: 0.9187 - val_loss: 0.6468 - val_accuracy: 0.7900
# Epoch 12/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.1496 - accuracy: 0.9392 - val_loss: 0.7594 - val_accuracy: 0.7950
# Epoch 13/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.1196 - accuracy: 0.9545 - val_loss: 0.8669 - val_accuracy: 0.7570
# Epoch 14/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0938 - accuracy: 0.9650 - val_loss: 1.1220 - val_accuracy: 0.7850
# Epoch 15/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.0898 - accuracy: 0.9675 - val_loss: 0.9801 - val_accuracy: 0.8110
# Epoch 16/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0803 - accuracy: 0.9720 - val_loss: 1.1014 - val_accuracy: 0.7790
# Epoch 17/30
# 125/125 [==============================] - 4s 34ms/step - loss: 0.0699 - accuracy: 0.9750 - val_loss: 1.6020 - val_accuracy: 0.7590
# Epoch 18/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0578 - accuracy: 0.9803 - val_loss: 1.1696 - val_accuracy: 0.7910
# Epoch 19/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.0583 - accuracy: 0.9800 - val_loss: 1.3239 - val_accuracy: 0.7690
# Epoch 20/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0597 - accuracy: 0.9803 - val_loss: 1.4526 - val_accuracy: 0.7780
# Epoch 21/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0520 - accuracy: 0.9843 - val_loss: 1.5558 - val_accuracy: 0.7870
# Epoch 22/30
# 125/125 [==============================] - 3s 26ms/step - loss: 0.0543 - accuracy: 0.9837 - val_loss: 2.0676 - val_accuracy: 0.7400
# Epoch 23/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.0519 - accuracy: 0.9833 - val_loss: 1.7588 - val_accuracy: 0.7620
# Epoch 24/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0652 - accuracy: 0.9825 - val_loss: 1.5697 - val_accuracy: 0.7770
# Epoch 25/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0653 - accuracy: 0.9827 - val_loss: 1.7340 - val_accuracy: 0.7820
# Epoch 26/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0371 - accuracy: 0.9885 - val_loss: 1.9194 - val_accuracy: 0.7880
# Epoch 27/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.0515 - accuracy: 0.9895 - val_loss: 1.9331 - val_accuracy: 0.7810
# Epoch 28/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0564 - accuracy: 0.9860 - val_loss: 1.9356 - val_accuracy: 0.7860
# Epoch 29/30
# 125/125 [==============================] - 3s 25ms/step - loss: 0.0419 - accuracy: 0.9875 - val_loss: 2.1879 - val_accuracy: 0.7530
# Epoch 30/30
# 125/125 [==============================] - 3s 24ms/step - loss: 0.0512 - accuracy: 0.9858 - val_loss: 2.4437 - val_accuracy: 0.7680

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 [==============================] - 1s 14ms/step - loss: 0.5086 - accuracy: 0.7490
# Test accuracy: 0.749

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **Training the regularized convnet**

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=60,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/60
# 125/125 [==============================] - 4s 26ms/step - loss: 0.7029 - accuracy: 0.5270 - val_loss: 0.6823 - val_accuracy: 0.5140
# Epoch 2/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.6743 - accuracy: 0.5982 - val_loss: 0.6413 - val_accuracy: 0.6620
# Epoch 3/60
# Epoch 44/60
# 125/125 [==============================] - 4s 27ms/step - loss: 0.3033 - accuracy: 0.8808 - val_loss: 0.3774 - val_accuracy: 0.8520
# Epoch 45/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2985 - accuracy: 0.8792 - val_loss: 0.4701 - val_accuracy: 0.7750
# Epoch 46/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2998 - accuracy: 0.8767 - val_loss: 0.4336 - val_accuracy: 0.8670
# Epoch 47/60
# 125/125 [==============================] - 3s 26ms/step - loss: 0.2945 - accuracy: 0.8857 - val_loss: 0.3762 - val_accuracy: 0.8620
# Epoch 48/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2985 - accuracy: 0.8817 - val_loss: 0.3759 - val_accuracy: 0.8660
# Epoch 49/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3011 - accuracy: 0.8838 - val_loss: 0.4230 - val_accuracy: 0.8310
# Epoch 50/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2873 - accuracy: 0.8792 - val_loss: 0.4090 - val_accuracy: 0.8560
# Epoch 51/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2962 - accuracy: 0.8802 - val_loss: 0.3889 - val_accuracy: 0.8770
# Epoch 52/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.3009 - accuracy: 0.8827 - val_loss: 0.7681 - val_accuracy: 0.8400
# Epoch 53/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2971 - accuracy: 0.8805 - val_loss: 0.5896 - val_accuracy: 0.8730
# Epoch 54/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2948 - accuracy: 0.8895 - val_loss: 0.4035 - val_accuracy: 0.8850
# Epoch 55/60
# 125/125 [==============================] - 4s 28ms/step - loss: 0.2998 - accuracy: 0.8840 - val_loss: 0.3815 - val_accuracy: 0.8540
# Epoch 56/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2743 - accuracy: 0.8923 - val_loss: 0.4725 - val_accuracy: 0.8620
# Epoch 57/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2875 - accuracy: 0.8870 - val_loss: 0.4797 - val_accuracy: 0.8690
# Epoch 58/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2877 - accuracy: 0.8840 - val_loss: 1.0777 - val_accuracy: 0.7620
# Epoch 59/60
# 125/125 [==============================] - 3s 25ms/step - loss: 0.2867 - accuracy: 0.8892 - val_loss: 0.5057 - val_accuracy: 0.8720
# Epoch 60/60
# 125/125 [==============================] - 3s 26ms/step - loss: 0.2824 - accuracy: 0.8898 - val_loss: 0.4907 - val_accuracy: 0.8690

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 [==============================] - 1s 15ms/step - loss: 0.3641 - accuracy: 0.8410
# Test accuracy: 0.841
